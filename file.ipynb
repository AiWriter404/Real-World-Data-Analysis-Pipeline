# %%
# 1. Load Dataset
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt 
# Load the dataset titanic dataset
titanic = sns.load_dataset('titanic')
df = pd.DataFrame(titanic)
# Display the first few rows of the dataset
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 2. Inspect Data
# Get summary statistics of the dataset
titanic.describe()
# Check for missing values in the dataset
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Check for missing values in the dataset
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Missing Values Remove
# Remove rows with missing values
df_cleaned = df.dropna()
# Check the shape of the cleaned dataset
df_cleaned.shape
# Out:
# (182, 15)

# %%
# Fill Missing Values
# Fill missing values with the mean of the column
df_filled = df.fillna(df.mean(numeric_only=True))

# %%
# Remove Duplicates
# Remove duplicate rows from the dataset
df_no_duplicates = df.drop_duplicates()
# Check the shape of the dataset after removing duplicates
df_no_duplicates.shape
# Out:
# (784, 15)

# %%
#  Data Visualization
# Visualize the distribution of ages in the dataset
sns.histplot(df['age'])
# Visualize the distribution of fares in the dataset
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Group by 'class' and calculate the mean age for each class
mean_age_by_class = df.groupby('class')['age'].mean()
# Visualize the mean age by class
sns.barplot(x=mean_age_by_class.index, y=mean_age_by_class.values)
# Out:
# C:\Users\aiwri\AppData\Local\Temp\ipykernel_2452\3630487007.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_age_by_class = df.groupby('class')['age'].mean()
# <Axes: xlabel='class'>

# %%
# Group by Age and calculate the mean fare for each age group
mean_fare_by_age = df.groupby('age')['fare'].mean()
# Visualize the mean fare by age        
sns.barplot(x=mean_fare_by_age.index, y=mean_fare_by_age.values)
# Out:
# <Axes: xlabel='age'>

# %%
# Group by servived and calculate the mean age for each group
mean_age_by_survived = df.groupby('survived')['age'].mean()
# Visualize the mean age by survived        
sns.barplot(x=mean_age_by_survived.index, y=mean_age_by_survived.values)
# Out:
# <Axes: xlabel='survived'>
